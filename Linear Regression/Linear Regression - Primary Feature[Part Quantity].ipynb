# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import preprocessing

# %%
dataset = pd.read_excel('Linear Regression Multi Features.xlsx',sheetname='Python')

# %%
dataset.set_index('Year')
# Out:
#             Oil Price  Total Sales  MC205-CNE-9-808       \
# Year
# 2016-01-01      29.78   1380587.63                    26
# 2016-02-01      31.03    970876.71                    30
# 2016-03-03      37.34    867645.65                    62
# 2016-04-03      40.75    449015.42                     6
# 2016-05-04      45.94    478956.43                   126
# 2016-06-04      47.69    689156.57                    26
# 2016-07-05      44.13    714379.72                     6
# 2016-08-05      44.88    718470.11                    57
# 2016-09-05      45.04    686869.04                    35
# 2016-10-06      49.29    616082.58                    30
# 2016-11-06      45.26   1077952.34                    29
# 2016-12-07      52.62   1072832.56                    63
# 2017-01-07      53.59   1059899.85                    42
# 2017-02-07      54.35    719201.81                   254
# 2017-03-10      50.90    888970.78                    39
# ...

# %%
dataset.describe()
# Out:
#        Oil Price   Total Sales  MC205-CNE-9-808       KTA00004-V            \
# count  28.000000  2.800000e+01             28.000000             28.000000
# mean   50.358929  1.052993e+06             74.678571             55.250000
# std     9.546150  3.877820e+05             76.925675             57.004629
# min    29.780000  4.490154e+05              2.000000              4.000000
# 25%    45.205000  7.190189e+05             26.000000             25.250000
# 50%    49.915000  1.066366e+06             37.000000             37.500000
# 75%    54.492500  1.265529e+06            118.500000             59.750000
# max    68.790000  2.046600e+06            254.000000            231.000000
#
#        ACTVCAX06-00002            MC205
# count             28.000000   28.000000
# mean              65.285714  100.428571
# std               47.075084   83.959615
# min                3.000000    6.000000
# 25%               26.750000   38.000000
# 50%               65.000000   61.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
# Year                    28 non-null datetime64[ns]
# Oil Price               28 non-null float64
# Total Sales             28 non-null float64
# MC205-CNE-9-808         28 non-null int64
# KTA00004-V              28 non-null int64
# ACTVCAX06-00002         28 non-null int64
# MC205                   28 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 1.6 KB

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')
sns.jointplot(x='Oil Price', y='Total Sales',data=dataset)

# %%
sns.jointplot(x='Oil Price', y='Total Sales',kind ='hex',data=dataset)

# %%
sns.pairplot(dataset)

# %%
sns.lmplot(x='Oil Price',y='MC205-CNE-9-808',data=dataset)

# %%
y = dataset['MC205-CNE-9-808']

# %%
dataset.columns
# Out:
# Index(['Year', 'Oil Price', 'Total Sales', 'MC205-CNE-9-808', 'KTA00004-V',
#        'ACTVCAX06-00002', 'MC205'],
#       dtype='object')

# %%
dataset.columns=dataset.columns.str.strip()

# %%
X = dataset[['Oil Price']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# The coefficients
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 2.31265464]

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0,0.5,'Predicted Y')

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 70.5094330881
# MSE: 8780.65321445
# RMSE: 93.705139744

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#            Coeffecient
# Oil Price     2.312655

# %%
lm.intercept_
# Out:
# -58.380001139271364

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,predictions)
# Out:
# -0.095417863434128281
